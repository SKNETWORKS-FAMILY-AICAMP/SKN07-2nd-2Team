# %% [markdown]
# # 2024.12.16.월 day36

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 데이터 불러오기

# %%
pwd
# Out:
# '/home/encore/workspace/git/SKN07-2nd-2Team'

# %%
# df_tt = pd.read_csv('../data/prj2_20241216/cell2cellholdout.csv')
# df_tt.isnull().sum()

# %%
import pandas as pd

df_raw = pd.read_csv('../data/prj2_20241216/cell2celltrain.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
#  13  CustomerCareCalls          51047 non-null  float64
#  14  ThreewayCalls              51047 non-null  float64
#  15  ReceivedCalls              51047 non-null  float64
#  16  OutboundCalls              51047 non-null  float64
#  17  InboundCalls               51047 non-null  float64
#  18  PeakCallsInOut             51047 non-null  float64
#  19  OffPeakCallsInOut          51047 non-null  float64
#  20  DroppedBlockedCalls        51047 non-null  float64
#  21  CallForwardingCalls        51047 non-null  float64
#  22  CallWaitingCalls           51047 non-null  float64
#  23  MonthsInService            51047 non-null  int64
#  24  UniqueSubs                 51047 non-null  int64
#  25  ActiveSubs                 51047 non-null  int64
#  26  ServiceArea                51023 non-null  object
#  27  Handsets                   51046 non-null  float64
#  28  HandsetModels              51046 non-null  float64
#  29  CurrentEquipmentDays       51046 non-null  float64
#  30  AgeHH1                     50138 non-null  float64
#  31  AgeHH2                     50138 non-null  float64
#  32  ChildrenInHH               51047 non-null  object
#  33  HandsetRefurbished         51047 non-null  object
#  34  HandsetWebCapable          51047 non-null  object
#  35  TruckOwner                 51047 non-null  object
#  36  RVOwner                    51047 non-null  object
#  37  Homeownership              51047 non-null  object
#  38  BuysViaMailOrder           51047 non-null  object
#  39  RespondsToMailOffers       51047 non-null  object
#  40  OptOutMailings             51047 non-null  object
#  41  NonUSTravel                51047 non-null  object
#  42  OwnsComputer               51047 non-null  object
#  43  HasCreditCard              51047 non-null  object
#  44  RetentionCalls             51047 non-null  int64
#  45  RetentionOffersAccepted    51047 non-null  int64
#  46  NewCellphoneUser           51047 non-null  object
#  47  NotNewCellphoneUser        51047 non-null  object
#  48  ReferralsMadeBySubscriber  51047 non-null  int64
#  49  IncomeGroup                51047 non-null  int64
#  50  OwnsMotorcycle             51047 non-null  object
#  51  AdjustmentsToCreditRating  51047 non-null  int64
#  52  HandsetPrice               51047 non-null  object
#  53  MadeCallToRetentionTeam    51047 non-null  object
#  54  CreditRating               51047 non-null  object
#  55  PrizmCode                  51047 non-null  object
#  56  Occupation                 51047 non-null  object
#  57  MaritalStatus              51047 non-null  object
# dtypes: float64(26), int64(9), object(23)
# memory usage: 22.6+ MB

# %% [markdown]
# ### 컬럼 확인
#
# CustomerID: 고객을 고유하게 식별하는 ID.
# Churn: 고객이 서비스를 해지했는지를 나타내는 컬럼. 예: 'Yes' (해지) 또는 'No' (유지).
# MonthlyRevenue: 고객이 매달 지불하는 평균 요금.
# MonthlyMinutes: 고객이 매달 사용한 평균 통화 시간(분 단위).
# TotalRecurringCharge: 반복적으로 청구되는 월간 요금.
# DirectorAssistedCalls: 상담원의 도움을 받은 통화 횟수.
# OverageMinutes: 정해진 요금제 통화 시간을 초과한 통화 시간(분 단위).
# RoamingCalls: 로밍 상태에서의 통화 횟수.
# PercChangeMinutes: 고객의 통화 시간 변동 비율.
# PercChangeRevenues: 고객의 월간 요금 변동 비율.
# DroppedCalls: 통화 중 끊긴 횟수.
# BlockedCalls: 통화 연결이 실패한 횟수.
# UnansweredCalls: 부재중 전화(응답하지 않은 통화) 횟수.
# CustomerCareCalls: 고객 센터에 걸려온 전화 횟수.
# ThreewayCalls: 삼자 통화 횟수.
# ReceivedCalls: 수신 통화 횟수.
# OutboundCalls: 발신 통화 횟수.
# InboundCalls: 수신 통화 횟수.
# PeakCallsInOut: 피크 시간대 발신 및 수신 통화 횟수.
# OffPeakCallsInOut: 비피크 시간대 발신 및 수신 통화 횟수.
# DroppedBlockedCalls: 끊긴 통화와 연결 실패 통화의 총합.
# CallForwardingCalls: 착신 전환된 통화 횟수.
# CallWaitingCalls: 통화 대기 중인 통화 횟수.
# MonthsInService: 고객이 서비스를 이용한 기간(개월 수).
# UniqueSubs: 계정에 연결된 고유 사용자 수.
# ActiveSubs: 현재 활성화된 사용자 수.
# ServiceArea: 고객이 속한 서비스 지역.
# Handsets: 고객이 보유한 휴대폰 수.
# HandsetModels: 고객이 사용하는 휴대폰 모델 수.
# CurrentEquipmentDays: 현재 휴대폰을 사용한 일수.
# AgeHH1: 주 가구원의 연령.
# AgeHH2: 두 번째 가구원의 연령.
# ChildrenInHH: 가구 내 자녀의 유무.
# HandsetRefurbished: 리퍼비시 휴대폰 사용 여부.
# HandsetWebCapable: 웹 접속 가능한 휴대폰 사용 여부.
# TruckOwner: 트럭 소유 여부.
# RVOwner: RV(레저용 차량) 소유 여부.
# Homeownership: 주택 소유 여부.
# BuysViaMailOrder: 우편 주문으로 물건을 구매한 적이 있는지 여부.
# RespondsToMailOffers: 우편으로 온 프로모션 제안에 반응했는지 여부.
# OptOutMailings: 우편물 수신 거부 여부.
# NonUSTravel: 미국 외 국가로 여행 경험 여부.
# OwnsComputer: 컴퓨터 소유 여부.
# HasCreditCard: 신용카드 소유 여부.
# RetentionCalls: 서비스 유지 관련 전화 횟수.
# RetentionOffersAccepted: 서비스 유지 제안을 수락한 횟수.
# NewCellphoneUser: 새 휴대폰 사용자 여부.
# NotNewCellphoneUser: 기존 휴대폰 사용자 여부.
# ReferralsMadeBySubscriber: 가입자가 만든 추천 수.
# IncomeGroup: 소득 수준을 나타내는 그룹 (1~n 수준).
# OwnsMotorcycle: 오토바이 소유 여부.
# AdjustmentsToCreditRating: 신용 등급 조정 횟수.
# HandsetPrice: 휴대폰 가격대.
# MadeCallToRetentionTeam: 서비스 유지 팀에 전화한 적이 있는지 여부.
# CreditRating: 고객의 신용 등급.
# PrizmCode: 고객의 라이프스타일 세그먼트를 나타내는 코드.
# Occupation: 고객의 직업.
# MaritalStatus: 고객의 혼인 상태

# %% [markdown]
# ### 결측치 확인

# %%
df_raw.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# MonthlyRevenue               156
# MonthlyMinutes               156
# TotalRecurringCharge         156
# DirectorAssistedCalls        156
# OverageMinutes               156
# RoamingCalls                 156
# PercChangeMinutes            367
# PercChangeRevenues           367
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                   24
# Handsets                       1
# HandsetModels                  1
# CurrentEquipmentDays           1
# AgeHH1                       909
# AgeHH2                       909
# ChildrenInHH                   0
# HandsetRefurbished             0
# HandsetWebCapable              0
# TruckOwner                     0
# RVOwner                        0
# Homeownership                  0
# BuysViaMailOrder               0
# RespondsToMailOffers           0
# OptOutMailings                 0
# NonUSTravel                    0
# OwnsComputer                   0
# HasCreditCard                  0
# RetentionCalls                 0
# RetentionOffersAccepted        0
# NewCellphoneUser               0
# NotNewCellphoneUser            0
# ReferralsMadeBySubscriber      0
# IncomeGroup                    0
# OwnsMotorcycle                 0
# AdjustmentsToCreditRating      0
# HandsetPrice                   0
# MadeCallToRetentionTeam        0
# CreditRating                   0
# PrizmCode                      0
# Occupation                     0
# MaritalStatus                  0
# dtype: int64

# %%
import missingno
missingno.matrix(df_raw)
# Out:
# <Axes: >

# %% [markdown]
# ### 데이터 값 확인

# %%
df_raw.shape
# Out:
# (51047, 58)

# %%
df_raw.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# 0               -19.0  ...                          0            4
# 1                 0.0  ...                          0            5
# 2                 0.0  ...                          0            6
# 3                 8.1  ...                          0            6
# 4                -0.2  ...                          0            9
#
#    OwnsMotorcycle  AdjustmentsToCreditRating  HandsetPrice  \
# 0              No                          0            30
# 1              No                          0            30
# 2              No                          0       Unknown
# 3              No                          0            10
# 4              No                          1            10
#
#    MadeCallToRetentionTeam  CreditRating  PrizmCode    Occupation  \
# 0                      Yes     1-Highest   Suburban  Professional
# 1                       No      4-Medium   Suburban  Professional
# 2                       No        3-Good       Town        Crafts
# 3                       No      4-Medium      Other         Other
# 4                       No     1-Highest      Other  Professional
#
#    MaritalStatus
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4            Yes
#
# [5 rows x 58 columns]

# %%
df_raw.Churn.value_counts(normalize=True)
# Out:
# Churn
# No     0.711815
# Yes    0.288185
# Name: proportion, dtype: float64

# %%
# 결측치 있는 컬럼 수 = 14
# 각 컬럼별 결측치 비율 2% 미만
# 우선 결측치 있는 행은 모두 삭제
df_drop = df_raw.dropna()

# 고객 ID 삭제
df_drop.drop(columns='CustomerID', inplace=True)
# Out:
# /tmp/ipykernel_33288/760278249.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop.drop(columns='CustomerID', inplace=True)

# %%
df_drop.shape
# Out:
# (49752, 57)

# %% [markdown]
# ## 2. EDA

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49752 entries, 0 to 51043
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      49752 non-null  object
#  1   MonthlyRevenue             49752 non-null  float64
#  2   MonthlyMinutes             49752 non-null  float64
#  3   TotalRecurringCharge       49752 non-null  float64
#  4   DirectorAssistedCalls      49752 non-null  float64
#  5   OverageMinutes             49752 non-null  float64
#  6   RoamingCalls               49752 non-null  float64
#  7   PercChangeMinutes          49752 non-null  float64
#  8   PercChangeRevenues         49752 non-null  float64
#  9   DroppedCalls               49752 non-null  float64
#  10  BlockedCalls               49752 non-null  float64
#  11  UnansweredCalls            49752 non-null  float64
#  12  CustomerCareCalls          49752 non-null  float64
#  13  ThreewayCalls              49752 non-null  float64
#  14  ReceivedCalls              49752 non-null  float64
#  15  OutboundCalls              49752 non-null  float64
#  16  InboundCalls               49752 non-null  float64
#  17  PeakCallsInOut             49752 non-null  float64
#  18  OffPeakCallsInOut          49752 non-null  float64
#  19  DroppedBlockedCalls        49752 non-null  float64
#  20  CallForwardingCalls        49752 non-null  float64
#  21  CallWaitingCalls           49752 non-null  float64
#  22  MonthsInService            49752 non-null  int64
#  23  UniqueSubs                 49752 non-null  int64
#  24  ActiveSubs                 49752 non-null  int64
#  25  ServiceArea                49752 non-null  object
#  26  Handsets                   49752 non-null  float64
#  27  HandsetModels              49752 non-null  float64
#  28  CurrentEquipmentDays       49752 non-null  float64
#  29  AgeHH1                     49752 non-null  float64
#  30  AgeHH2                     49752 non-null  float64
#  31  ChildrenInHH               49752 non-null  object
#  32  HandsetRefurbished         49752 non-null  object
#  33  HandsetWebCapable          49752 non-null  object
#  34  TruckOwner                 49752 non-null  object
#  35  RVOwner                    49752 non-null  object
#  36  Homeownership              49752 non-null  object
#  37  BuysViaMailOrder           49752 non-null  object
#  38  RespondsToMailOffers       49752 non-null  object
#  39  OptOutMailings             49752 non-null  object
#  40  NonUSTravel                49752 non-null  object
#  41  OwnsComputer               49752 non-null  object
#  42  HasCreditCard              49752 non-null  object
#  43  RetentionCalls             49752 non-null  int64
#  44  RetentionOffersAccepted    49752 non-null  int64
#  45  NewCellphoneUser           49752 non-null  object
#  46  NotNewCellphoneUser        49752 non-null  object
#  47  ReferralsMadeBySubscriber  49752 non-null  int64
#  48  IncomeGroup                49752 non-null  int64
#  49  OwnsMotorcycle             49752 non-null  object
#  50  AdjustmentsToCreditRating  49752 non-null  int64
#  51  HandsetPrice               49752 non-null  object
#  52  MadeCallToRetentionTeam    49752 non-null  object
#  53  CreditRating               49752 non-null  object
#  54  PrizmCode                  49752 non-null  object
#  55  Occupation                 49752 non-null  object
#  56  MaritalStatus              49752 non-null  object
# dtypes: float64(26), int64(8), object(23)
# memory usage: 22.0+ MB

# %% [markdown]
# ### object 컬럼 라벨링

# %%
df_drop.columns[df_drop.dtypes=='object']
# Out:
# Index(['Churn', 'ServiceArea', 'ChildrenInHH', 'HandsetRefurbished',
#        'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership',
#        'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings',
#        'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'NewCellphoneUser',
#        'NotNewCellphoneUser', 'OwnsMotorcycle', 'HandsetPrice',
#        'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
#        'MaritalStatus'],
#       dtype='object')

# %%
# # Object 컬럼 내 값 확인
# for col in df_drop.columns[df_drop.dtypes=='object']:
#     print(df_drop[col].nunique())
#     print(df_drop[col].value_counts(normalize=True))
#     print()

# %%
# df_ttt = df_drop.copy()
# df_ttt['CreditRating'] = df_ttt['CreditRating'].apply(lambda x: int(x[0]))
# df_ttt.groupby(['IncomeGroup'], as_index=False)[['MonthlyRevenue']].mean()

# %%
# 민혁

# 이상치 처리

# HandsetPrice: 휴대폰 가격대
# Unknown -> 소득수준 컬럼 IncomeGroup 로 그룹화해서 평균값 채워넣기

df_encoding = df_drop.copy()

price_data = df_encoding[df_encoding.HandsetPrice != 'Unknown']
price_data.loc[:,'HandsetPrice'] = price_data['HandsetPrice'].astype('int64')
handset_mean_price = price_data.groupby(['IncomeGroup'])[['HandsetPrice']].mean()

for i,y in handset_mean_price.iterrows():
    df_encoding.loc[(df_encoding.HandsetPrice == 'Unknown') & (df_encoding.IncomeGroup == i), 'HandsetPrice'] = round(y.values[0])

df_encoding['HandsetPrice'] = df_encoding['HandsetPrice'].astype('int64')

# %%
# 재철

# 범주형 컬럼 라벨링

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# CreditRating: 소득수준 그룹 (순서 변환)
df_encoding['IncomeGroup'] = df_encoding['IncomeGroup'].apply(lambda x: 10-x)

# CreditRating: 신용등급 (순서 변환)
credit_rating_mapping = { '1-Highest': 7, '2-High': 6, '3-Good': 5, '4-Medium': 4, '5-Low': 3, '6-VeryLow': 2, '7-Lowest': 1 }
df_encoding['CreditRating'] = df_encoding['CreditRating'].map(credit_rating_mapping)

# PrizmCode: 라이프스타일 구분 (라벨인코딩)
df_encoding['PrizmCode'] = le.fit_transform(df_encoding['PrizmCode'])  
# Occupation: 직업 (라벨인코딩)
df_encoding['Occupation'] = le.fit_transform(df_encoding['Occupation'])
# ServiceArea: 서비스 지역 (라벨인코딩)
df_encoding['ServiceArea'] = le.fit_transform(df_encoding['ServiceArea'])

# %%
# 수민

# BIT 여부 컬럼
# No/Yes = 0/1 라벨링

col_object = df_encoding.columns[df_encoding.dtypes=='object']
col_bit = [col for col in col_object if 'Yes' in list(df_encoding[col].unique())]

# MaritalStatus: 혼인 여부 (Yes/No/Unknown)
col_bit.remove('MaritalStatus')
df_encoding['MaritalStatus'] = df_encoding['MaritalStatus'].apply(lambda x: -1 if x == 'Unknown' else x)
df_encoding['MaritalStatus'] = df_encoding['MaritalStatus'].apply(lambda x: 1 if x == 'Yes' else 0)

# Homeownership: 주택 소유 여부 (Known/Unknown)
df_encoding['Homeownership'] = df_encoding['Homeownership'].apply(lambda x: 1 if x == 'Known' else 0)

# 기타 여부 컬럼들 (Yes/No)
for col in col_bit:
    df_encoding[col] = df_encoding[col].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df_encoding.to_csv('../data/prj2_20241216/df_encoding.csv', encoding='utf-8')

# %%
df_encoding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49752 entries, 0 to 51043
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      49752 non-null  int64
#  1   MonthlyRevenue             49752 non-null  float64
#  2   MonthlyMinutes             49752 non-null  float64
#  3   TotalRecurringCharge       49752 non-null  float64
#  4   DirectorAssistedCalls      49752 non-null  float64
#  5   OverageMinutes             49752 non-null  float64
#  6   RoamingCalls               49752 non-null  float64
#  7   PercChangeMinutes          49752 non-null  float64
#  8   PercChangeRevenues         49752 non-null  float64
#  9   DroppedCalls               49752 non-null  float64
#  10  BlockedCalls               49752 non-null  float64
#  11  UnansweredCalls            49752 non-null  float64
#  12  CustomerCareCalls          49752 non-null  float64
#  13  ThreewayCalls              49752 non-null  float64
#  14  ReceivedCalls              49752 non-null  float64
#  15  OutboundCalls              49752 non-null  float64
#  16  InboundCalls               49752 non-null  float64
#  17  PeakCallsInOut             49752 non-null  float64
#  18  OffPeakCallsInOut          49752 non-null  float64
#  19  DroppedBlockedCalls        49752 non-null  float64
#  20  CallForwardingCalls        49752 non-null  float64
#  21  CallWaitingCalls           49752 non-null  float64
#  22  MonthsInService            49752 non-null  int64
#  23  UniqueSubs                 49752 non-null  int64
#  24  ActiveSubs                 49752 non-null  int64
#  25  ServiceArea                49752 non-null  int64
#  26  Handsets                   49752 non-null  float64
#  27  HandsetModels              49752 non-null  float64
#  28  CurrentEquipmentDays       49752 non-null  float64
#  29  AgeHH1                     49752 non-null  float64
#  30  AgeHH2                     49752 non-null  float64
#  31  ChildrenInHH               49752 non-null  int64
#  32  HandsetRefurbished         49752 non-null  int64
#  33  HandsetWebCapable          49752 non-null  int64
#  34  TruckOwner                 49752 non-null  int64
#  35  RVOwner                    49752 non-null  int64
#  36  Homeownership              49752 non-null  int64
#  37  BuysViaMailOrder           49752 non-null  int64
#  38  RespondsToMailOffers       49752 non-null  int64
#  39  OptOutMailings             49752 non-null  int64
#  40  NonUSTravel                49752 non-null  int64
#  41  OwnsComputer               49752 non-null  int64
#  42  HasCreditCard              49752 non-null  int64
#  43  RetentionCalls             49752 non-null  int64
#  44  RetentionOffersAccepted    49752 non-null  int64
#  45  NewCellphoneUser           49752 non-null  int64
#  46  NotNewCellphoneUser        49752 non-null  int64
#  47  ReferralsMadeBySubscriber  49752 non-null  int64
#  48  IncomeGroup                49752 non-null  int64
#  49  OwnsMotorcycle             49752 non-null  int64
#  50  AdjustmentsToCreditRating  49752 non-null  int64
#  51  HandsetPrice               49752 non-null  int64
#  52  MadeCallToRetentionTeam    49752 non-null  int64
#  53  CreditRating               49752 non-null  int64
#  54  PrizmCode                  49752 non-null  int64
#  55  Occupation                 49752 non-null  int64
#  56  MaritalStatus              49752 non-null  int64
# dtypes: float64(26), int64(31)
# memory usage: 22.0 MB

# %%
# 혼인여부 관련 컬럼 상관관계 확인
df_corr = df_encoding[['Churn', 'MaritalStatus','AgeHH1','AgeHH2','ChildrenInHH']].corr()

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <Axes: >

# %%
test = pd.read_csv('./df_encoding.csv')

# %%
test.drop('Unnamed: 0',axis=1).corr()
# Out:
#                               Churn  MonthlyRevenue  MonthlyMinutes  \
# Churn                      1.000000       -0.012065       -0.050165
# MonthlyRevenue            -0.012065        1.000000        0.712734
# MonthlyMinutes            -0.050165        0.712734        1.000000
# TotalRecurringCharge      -0.058945        0.629391        0.585375
# DirectorAssistedCalls     -0.019714        0.407523        0.392950
# OverageMinutes             0.015301        0.787317        0.569083
# RoamingCalls               0.010955        0.304086        0.112028
# PercChangeMinutes         -0.033194       -0.027052       -0.044257
# PercChangeRevenues         0.013015       -0.014223       -0.038438
# DroppedCalls              -0.015062        0.429374        0.593149
# BlockedCalls              -0.004474        0.232651        0.318114
# UnansweredCalls           -0.028192        0.450751        0.645650
# CustomerCareCalls         -0.035331        0.189579        0.375238
# ThreewayCalls             -0.023716        0.200998        0.287670
# ReceivedCalls             -0.037097        0.604762        0.828206
# OutboundCalls             -0.032489        0.495088        0.694517
# InboundCalls              -0.033855        0.373419        0.558065
# PeakCallsInOut            -0.039527        0.642019        0.772486
# OffPeakCallsInOut         -0.040955        0.473354        0.765215
# DroppedBlockedCalls       -0.012353        0.417567        0.573916
# CallForwardingCalls       -0.003161        0.008935        0.018394
# CallWaitingCalls          -0.025509        0.469497        0.614970
# MonthsInService            0.017544        0.001205       -0.065558
# UniqueSubs                 0.032839       -0.014949       -0.028869
# ActiveSubs                 0.013049       -0.044068       -0.066116
# ServiceArea                0.003104        0.000193       -0.006439
# Handsets                  -0.033730        0.243892        0.303903
# HandsetModels             -0.040470        0.236179        0.293145
# CurrentEquipmentDays       0.102513       -0.216644       -0.311033
# AgeHH1                    -0.028761       -0.108608       -0.163928
# AgeHH2                    -0.017577       -0.105829       -0.143321
# ChildrenInHH               0.009505       -0.048084       -0.064239
# HandsetRefurbished         0.030026        0.045037        0.069743
# HandsetWebCapable         -0.062409        0.101267        0.142751
# TruckOwner                -0.004873       -0.037482       -0.056616
# RVOwner                   -0.003280       -0.013105       -0.031187
# Homeownership             -0.013716       -0.084317       -0.138943
# BuysViaMailOrder          -0.021884       -0.098505       -0.135862
# RespondsToMailOffers      -0.023082       -0.099121       -0.137442
# OptOutMailings             0.000880       -0.027080       -0.039811
# NonUSTravel               -0.002816       -0.042151       -0.051114
# OwnsComputer              -0.001231       -0.078887       -0.109123
# HasCreditCard             -0.009204       -0.081925       -0.125792
# RetentionCalls             0.058422        0.012019        0.011856
# RetentionOffersAccepted    0.034511        0.014795        0.014966
# NewCellphoneUser          -0.007639        0.009941        0.018157
# NotNewCellphoneUser        0.006900        0.046602        0.045769
# ReferralsMadeBySubscriber -0.011390        0.017879        0.064916
# IncomeGroup                0.012982        0.079309        0.145964
# OwnsMotorcycle             0.007700       -0.010377       -0.016976
# AdjustmentsToCreditRating -0.016123        0.035417        0.045723
# HandsetPrice               0.000044        0.110935        0.155595
# MadeCallToRetentionTeam    0.060577        0.012137        0.009875
# CreditRating               0.047741       -0.139504       -0.206566
# PrizmCode                  0.005204       -0.051784       -0.080951
# Occupation                -0.005276       -0.032440       -0.043907
# MaritalStatus             -0.004567       -0.097874       -0.148732
#
#                            TotalRecurringCharge  DirectorAssistedCalls  \
# Churn                                 -0.058945              -0.019714
# MonthlyRevenue                         0.629391               0.407523
# MonthlyMinutes                         0.585375               0.392950
# TotalRecurringCharge                   1.000000               0.311440
# DirectorAssistedCalls                  0.311440               1.000000
# OverageMinutes                         0.201011               0.287109
# RoamingCalls                           0.073855               0.070134
# PercChangeMinutes                     -0.016284              -0.025542
# PercChangeRevenues                    -0.024126              -0.014696
# DroppedCalls                           0.354148               0.262960
# BlockedCalls                           0.178584               0.140135
# UnansweredCalls                        0.359008               0.306220
# CustomerCareCalls                      0.153056               0.094066
# ThreewayCalls                          0.148344               0.134143
# ReceivedCalls                          0.482062               0.282247
# OutboundCalls                          0.410429               0.315242
# InboundCalls                           0.307202               0.186776
# PeakCallsInOut                         0.552995               0.419658
# OffPeakCallsInOut                      0.369690               0.274796
# DroppedBlockedCalls                    0.335165               0.253054
# CallForwardingCalls                    0.009562               0.002759
# CallWaitingCalls                       0.355959               0.308005
# MonthsInService                       -0.045156               0.017889
# UniqueSubs                            -0.020638              -0.001969
# ActiveSubs                            -0.058606              -0.014442
# ServiceArea                           -0.002984              -0.008368
# Handsets                               0.235735               0.183002
# HandsetModels                          0.226597               0.170469
# CurrentEquipmentDays                  -0.247592              -0.120887
# AgeHH1                                -0.106111              -0.058874
# AgeHH2                                -0.101134              -0.057644
# ChildrenInHH                          -0.051004              -0.023476
# HandsetRefurbished                     0.029612               0.029736
# HandsetWebCapable                      0.137341               0.052832
# TruckOwner                            -0.036758              -0.032169
# RVOwner                               -0.015363              -0.006535
# Homeownership                         -0.083662              -0.042107
# BuysViaMailOrder                      -0.089861              -0.047796
# RespondsToMailOffers                  -0.090121              -0.048054
# OptOutMailings                        -0.023882              -0.012693
# NonUSTravel                           -0.035909              -0.022874
# OwnsComputer                          -0.068913              -0.044377
# HasCreditCard                         -0.085221              -0.041923
# RetentionCalls                        -0.017562               0.010556
# RetentionOffersAccepted               -0.002218               0.013857
# NewCellphoneUser                       0.004301               0.002679
# NotNewCellphoneUser                    0.049160               0.032330
# ReferralsMadeBySubscriber              0.036912              -0.005592
# IncomeGroup                            0.075415               0.014985
# OwnsMotorcycle                        -0.012066              -0.006430
# AdjustmentsToCreditRating              0.044019               0.022616
# HandsetPrice                           0.120079               0.062331
# MadeCallToRetentionTeam               -0.019139               0.011875
# CreditRating                          -0.134734              -0.075219
# PrizmCode                             -0.040246              -0.018149
# Occupation                            -0.023751              -0.011358
# MaritalStatus                         -0.092179              -0.038710
#
#                            OverageMinutes  RoamingCalls  PercChangeMinutes  \
# Churn                            0.015301      0.010955          -0.033194
# MonthlyRevenue                   0.787317      0.304086          -0.027052
# MonthlyMinutes                   0.569083      0.112028          -0.044257
# TotalRecurringCharge             0.201011      0.073855          -0.016284
# DirectorAssistedCalls            0.287109      0.070134          -0.025542
# OverageMinutes                   1.000000      0.062955          -0.026377
# RoamingCalls                     0.062955      1.000000          -0.055106
# PercChangeMinutes               -0.026377     -0.055106           1.000000
# PercChangeRevenues              -0.014570     -0.093108           0.607504
# DroppedCalls                     0.329464      0.066135          -0.082284
# BlockedCalls                     0.190967      0.029070          -0.054548
# UnansweredCalls                  0.362627      0.038768          -0.085781
# CustomerCareCalls                0.137185      0.020528          -0.040239
# ThreewayCalls                    0.164275      0.024108          -0.028807
# ReceivedCalls                    0.513705      0.045131          -0.106360
# OutboundCalls                    0.404062      0.045443          -0.062718
# InboundCalls                     0.317985      0.020652          -0.068281
# PeakCallsInOut                   0.517419      0.062736          -0.108065
# OffPeakCallsInOut                0.390702      0.031287          -0.089657
# DroppedBlockedCalls              0.328767      0.059513          -0.087335
# CallForwardingCalls              0.004307      0.003524          -0.003306
# CallWaitingCalls                 0.457071      0.036037          -0.128228
# MonthsInService                  0.003375     -0.009516           0.005496
# UniqueSubs                      -0.003472     -0.002963           0.002349
# ActiveSubs                      -0.014086     -0.002182           0.009994
# ServiceArea                     -0.003242      0.002049           0.011844
# Handsets                         0.143777      0.024344          -0.011222
# HandsetModels                    0.143102      0.022641          -0.010669
# CurrentEquipmentDays            -0.124190     -0.027969          -0.005830
# AgeHH1                          -0.065212     -0.010467           0.014243
# AgeHH2                          -0.062350     -0.012171           0.003986
# ChildrenInHH                    -0.025528     -0.002939           0.004608
# HandsetRefurbished               0.028613      0.000705          -0.006338
# HandsetWebCapable                0.051794      0.018510          -0.003700
# TruckOwner                      -0.024492      0.003906           0.006145
# RVOwner                         -0.008906      0.005853           0.005690
# Homeownership                   -0.046941     -0.016350           0.011896
# BuysViaMailOrder                -0.059292     -0.013196           0.010538
# RespondsToMailOffers            -0.060803     -0.011364           0.010303
# OptOutMailings                  -0.019473     -0.006176           0.000005
# NonUSTravel                     -0.027916     -0.008044           0.004419
# OwnsComputer                    -0.051888     -0.011759           0.010192
# HasCreditCard                   -0.044825     -0.020209           0.016591
# RetentionCalls                   0.014741     -0.002423          -0.021400
# RetentionOffersAccepted          0.008474     -0.000440          -0.008232
# NewCellphoneUser                 0.008415     -0.004476          -0.002904
# NotNewCellphoneUser              0.024433     -0.000512          -0.003368
# ReferralsMadeBySubscriber        0.008452     -0.007440           0.003520
# IncomeGroup                      0.048051      0.014034          -0.012162
# OwnsMotorcycle                  -0.008418      0.011445          -0.005296
# AdjustmentsToCreditRating        0.021671      0.004952          -0.004715
# HandsetPrice                     0.061584      0.022995          -0.010205
# MadeCallToRetentionTeam          0.014170     -0.002468          -0.023646
# CreditRating                    -0.081122     -0.015042           0.033717
# PrizmCode                       -0.031593     -0.000575          -0.002648
# Occupation                      -0.025246     -0.006858           0.005872
# MaritalStatus                   -0.059835     -0.006304           0.003234
#
#                            PercChangeRevenues  DroppedCalls  ...  \
# Churn                                0.013015     -0.015062  ...
# MonthlyRevenue                      -0.014223      0.429374  ...
# MonthlyMinutes                      -0.038438      0.593149  ...
# TotalRecurringCharge                -0.024126      0.354148  ...
# DirectorAssistedCalls               -0.014696      0.262960  ...
# OverageMinutes                      -0.014570      0.329464  ...
# RoamingCalls                        -0.093108      0.066135  ...
# PercChangeMinutes                    0.607504     -0.082284  ...
# PercChangeRevenues                   1.000000     -0.036180  ...
# DroppedCalls                        -0.036180      1.000000  ...
# BlockedCalls                        -0.031916      0.184385  ...
# UnansweredCalls                     -0.054309      0.541497  ...
# CustomerCareCalls                   -0.031468      0.293616  ...
# ThreewayCalls                        0.014467      0.261190  ...
# ReceivedCalls                       -0.078286      0.517244  ...
# OutboundCalls                       -0.038975      0.564891  ...
# InboundCalls                        -0.044919      0.395626  ...
# PeakCallsInOut                      -0.078299      0.573118  ...
# OffPeakCallsInOut                   -0.051762      0.600716  ...
# DroppedBlockedCalls                 -0.044256      0.717652  ...
# CallForwardingCalls                 -0.002710      0.004666  ...
# CallWaitingCalls                    -0.092176      0.397990  ...
# MonthsInService                     -0.005759     -0.044335  ...
# UniqueSubs                           0.002367     -0.020567  ...
# ActiveSubs                           0.005341     -0.050117  ...
# ServiceArea                          0.005408     -0.014264  ...
# Handsets                            -0.016845      0.225189  ...
# HandsetModels                       -0.015881      0.217574  ...
# CurrentEquipmentDays                 0.006046     -0.216252  ...
# AgeHH1                               0.006914     -0.119905  ...
# AgeHH2                               0.001920     -0.108245  ...
# ChildrenInHH                         0.001415     -0.040590  ...
# HandsetRefurbished                  -0.005103      0.056357  ...
# HandsetWebCapable                   -0.003704      0.087392  ...
# TruckOwner                           0.004135     -0.076157  ...
# RVOwner                              0.001866     -0.046610  ...
# Homeownership                        0.002730     -0.103417  ...
# BuysViaMailOrder                     0.004204     -0.100492  ...
# RespondsToMailOffers                 0.003557     -0.101689  ...
# OptOutMailings                       0.002266     -0.022874  ...
# NonUSTravel                          0.005741     -0.035262  ...
# OwnsComputer                         0.004988     -0.086671  ...
# HasCreditCard                        0.005594     -0.083956  ...
# RetentionCalls                      -0.018961      0.020417  ...
# RetentionOffersAccepted             -0.012295      0.014650  ...
# NewCellphoneUser                    -0.004846      0.016003  ...
# NotNewCellphoneUser                 -0.000782      0.013436  ...
# ReferralsMadeBySubscriber            0.001244      0.024921  ...
# IncomeGroup                         -0.005066      0.097358  ...
# OwnsMotorcycle                      -0.000453     -0.016397  ...
# AdjustmentsToCreditRating           -0.005234      0.031109  ...
# HandsetPrice                        -0.012415      0.108662  ...
# MadeCallToRetentionTeam             -0.020121      0.019678  ...
# CreditRating                         0.021758     -0.193695  ...
# PrizmCode                           -0.000193     -0.088821  ...
# Occupation                           0.005523     -0.038198  ...
# MaritalStatus                        0.002224     -0.117784  ...
#
#                            ReferralsMadeBySubscriber  IncomeGroup  \
# Churn                                      -0.011390     0.012982
# MonthlyRevenue                              0.017879     0.079309
# MonthlyMinutes                              0.064916     0.145964
# TotalRecurringCharge                        0.036912     0.075415
# DirectorAssistedCalls                      -0.005592     0.014985
# OverageMinutes                              0.008452     0.048051
# RoamingCalls                               -0.007440     0.014034
# PercChangeMinutes                           0.003520    -0.012162
# PercChangeRevenues                          0.001244    -0.005066
# DroppedCalls                                0.024921     0.097358
# BlockedCalls                                0.026000     0.065170
# UnansweredCalls                             0.035541     0.130559
# CustomerCareCalls                           0.051387     0.123287
# ThreewayCalls                               0.015789     0.046055
# ReceivedCalls                               0.047325     0.131878
# OutboundCalls                               0.060991     0.103839
# InboundCalls                                0.064289     0.101931
# PeakCallsInOut                              0.032142     0.086921
# OffPeakCallsInOut                           0.050841     0.145402
# DroppedBlockedCalls                         0.033071     0.103653
# CallForwardingCalls                         0.004423     0.008509
# CallWaitingCalls                            0.037633     0.066404
# MonthsInService                            -0.016004    -0.138320
# UniqueSubs                                 -0.025521    -0.052367
# ActiveSubs                                 -0.035187    -0.116604
# ServiceArea                                -0.004839     0.020063
# Handsets                                    0.033901     0.026853
# HandsetModels                               0.036132     0.023796
# CurrentEquipmentDays                       -0.030332    -0.136298
# AgeHH1                                     -0.021152    -0.641750
# AgeHH2                                     -0.010620    -0.470178
# ChildrenInHH                               -0.013045    -0.314820
# HandsetRefurbished                          0.012618     0.018126
# HandsetWebCapable                           0.027343     0.048993
# TruckOwner                                  0.003540    -0.237339
# RVOwner                                     0.006081    -0.183604
# Homeownership                              -0.009201    -0.713459
# BuysViaMailOrder                           -0.009856    -0.428400
# RespondsToMailOffers                       -0.010455    -0.436410
# OptOutMailings                             -0.002110    -0.057564
# NonUSTravel                                -0.001626    -0.162565
# OwnsComputer                                0.004233    -0.280054
# HasCreditCard                              -0.008396    -0.699924
# RetentionCalls                              0.006011     0.018722
# RetentionOffersAccepted                     0.007949     0.008379
# NewCellphoneUser                            0.018583    -0.005072
# NotNewCellphoneUser                         0.025377    -0.021377
# ReferralsMadeBySubscriber                   1.000000     0.011379
# IncomeGroup                                 0.011379     1.000000
# OwnsMotorcycle                              0.000199    -0.053361
# AdjustmentsToCreditRating                   0.015080    -0.007488
# HandsetPrice                                0.025565     0.106226
# MadeCallToRetentionTeam                     0.007459     0.018226
# CreditRating                               -0.007739    -0.269026
# PrizmCode                                  -0.003367    -0.202348
# Occupation                                  0.001576    -0.136354
# MaritalStatus                              -0.014295    -0.483221
#
#                            OwnsMotorcycle  AdjustmentsToCreditRating  \
# Churn                            0.007700                  -0.016123
# MonthlyRevenue                  -0.010377                   0.035417
# MonthlyMinutes                  -0.016976                   0.045723
# TotalRecurringCharge            -0.012066                   0.044019
# DirectorAssistedCalls           -0.006430                   0.022616
# OverageMinutes                  -0.008418                   0.021671
# RoamingCalls                     0.011445                   0.004952
# PercChangeMinutes               -0.005296                  -0.004715
# PercChangeRevenues              -0.000453                  -0.005234
# DroppedCalls                    -0.016397                   0.031109
# BlockedCalls                    -0.002109                   0.004748
# UnansweredCalls                 -0.010797                   0.036191
# CustomerCareCalls               -0.011022                   0.019791
# ThreewayCalls                   -0.009715                   0.003243
# ReceivedCalls                   -0.012424                   0.041543
# OutboundCalls                   -0.010683                   0.042581
# InboundCalls                    -0.000373                   0.038376
# PeakCallsInOut                  -0.006704                   0.069048
# OffPeakCallsInOut               -0.013246                   0.019380
# DroppedBlockedCalls             -0.011363                   0.021650
# CallForwardingCalls             -0.001503                   0.001322
# CallWaitingCalls                -0.005442                   0.023102
# MonthsInService                  0.017825                   0.221169
# UniqueSubs                       0.009425                  -0.001456
# ActiveSubs                       0.016277                  -0.003629
# ServiceArea                      0.006544                   0.020574
# Handsets                         0.002400                   0.187811
# HandsetModels                    0.002193                   0.167597
# CurrentEquipmentDays             0.015852                   0.036936
# AgeHH1                           0.068647                   0.017555
# AgeHH2                           0.072789                   0.005920
# ChildrenInHH                     0.053161                  -0.014705
# HandsetRefurbished               0.001773                   0.033824
# HandsetWebCapable               -0.000784                  -0.026885
# TruckOwner                       0.158404                   0.003677
# RVOwner                          0.100804                  -0.001691
# Homeownership                    0.069996                   0.011176
# BuysViaMailOrder                 0.055088                   0.001467
# RespondsToMailOffers             0.053439                   0.004904
# OptOutMailings                   0.005571                   0.003868
# NonUSTravel                      0.013685                   0.008281
# OwnsComputer                     0.045278                   0.002042
# HasCreditCard                    0.061232                   0.012215
# RetentionCalls                  -0.000796                   0.027617
# RetentionOffersAccepted         -0.002866                   0.024281
# NewCellphoneUser                 0.000792                   0.041379
# NotNewCellphoneUser              0.017565                   0.060411
# ReferralsMadeBySubscriber        0.000199                   0.015080
# IncomeGroup                     -0.053361                  -0.007488
# OwnsMotorcycle                   1.000000                  -0.000993
# AdjustmentsToCreditRating       -0.000993                   1.000000
# HandsetPrice                    -0.005480                  -0.054751
# MadeCallToRetentionTeam          0.001019                   0.023956
# CreditRating                     0.037209                   0.037843
# PrizmCode                        0.038921                  -0.016815
# Occupation                       0.002471                   0.015252
# MaritalStatus                    0.066298                   0.000052
#
#                            HandsetPrice  MadeCallToRetentionTeam  \
# Churn                          0.000044                 0.060577
# MonthlyRevenue                 0.110935                 0.012137
# MonthlyMinutes                 0.155595                 0.009875
# TotalRecurringCharge           0.120079                -0.019139
# DirectorAssistedCalls          0.062331                 0.011875
# OverageMinutes                 0.061584                 0.014170
# RoamingCalls                   0.022995                -0.002468
# PercChangeMinutes             -0.010205                -0.023646
# PercChangeRevenues            -0.012415                -0.020121
# DroppedCalls                   0.108662                 0.019678
# BlockedCalls                   0.045952                 0.013140
# UnansweredCalls                0.112911                 0.030651
# CustomerCareCalls              0.071814                 0.023392
# ThreewayCalls                  0.059294                 0.006193
# ReceivedCalls                  0.138366                 0.007371
# OutboundCalls                  0.145002                 0.011369
# InboundCalls                   0.140335                 0.006673
# PeakCallsInOut                 0.118488                 0.022532
# OffPeakCallsInOut              0.163679                 0.017239
# DroppedBlockedCalls            0.097455                 0.020729
# CallForwardingCalls            0.001051                 0.000431
# CallWaitingCalls               0.112092                 0.012125
# MonthsInService               -0.252136                 0.067855
# UniqueSubs                    -0.015445                -0.007067
# ActiveSubs                    -0.020448                -0.032336
# ServiceArea                   -0.017874                 0.003022
# Handsets                       0.084278                 0.101569
# HandsetModels                  0.040966                 0.101105
# CurrentEquipmentDays          -0.188791                -0.030148
# AgeHH1                        -0.107722                -0.008463
# AgeHH2                        -0.075857                -0.009890
# ChildrenInHH                  -0.040971                -0.006762
# HandsetRefurbished             0.065283                 0.076711
# HandsetWebCapable              0.104776                -0.011865
# TruckOwner                    -0.053099                -0.009981
# RVOwner                       -0.020576                -0.006834
# Homeownership                 -0.105284                -0.009404
# BuysViaMailOrder              -0.067085                -0.021335
# RespondsToMailOffers          -0.067949                -0.019282
# OptOutMailings                -0.012927                 0.002510
# NonUSTravel                   -0.017412                -0.009760
# OwnsComputer                  -0.044527                -0.017290
# HasCreditCard                 -0.101982                -0.006019
# RetentionCalls                -0.002358                 0.957705
# RetentionOffersAccepted       -0.001985                 0.699225
# NewCellphoneUser              -0.041895                -0.005202
# NotNewCellphoneUser           -0.046458                 0.017716
# ReferralsMadeBySubscriber      0.025565                 0.007459
# IncomeGroup                    0.106226                 0.018226
# OwnsMotorcycle                -0.005480                 0.001019
# AdjustmentsToCreditRating     -0.054751                 0.023956
# HandsetPrice                   1.000000                 0.000045
# MadeCallToRetentionTeam        0.000045                 1.000000
# CreditRating                  -0.108411                -0.008632
# PrizmCode                     -0.038675                -0.016188
# Occupation                    -0.013902                -0.006703
# MaritalStatus                 -0.078936                -0.021305
#
#                            CreditRating  PrizmCode  Occupation  MaritalStatus
# Churn                          0.047741   0.005204   -0.005276      -0.004567
# MonthlyRevenue                -0.139504  -0.051784   -0.032440      -0.097874
# MonthlyMinutes                -0.206566  -0.080951   -0.043907      -0.148732
# TotalRecurringCharge          -0.134734  -0.040246   -0.023751      -0.092179
# DirectorAssistedCalls         -0.075219  -0.018149   -0.011358      -0.038710
# OverageMinutes                -0.081122  -0.031593   -0.025246      -0.059835
# RoamingCalls                  -0.015042  -0.000575   -0.006858      -0.006304
# PercChangeMinutes              0.033717  -0.002648    0.005872       0.003234
# PercChangeRevenues             0.021758  -0.000193    0.005523       0.002224
# DroppedCalls                  -0.193695  -0.088821   -0.038198      -0.117784
# BlockedCalls                  -0.097657   0.003240   -0.025161      -0.036091
# UnansweredCalls               -0.229354  -0.076027   -0.046552      -0.111468
# CustomerCareCalls             -0.215857  -0.065139   -0.034046      -0.093974
# ThreewayCalls                 -0.104222  -0.051621   -0.017700      -0.052801
# ReceivedCalls                 -0.201088  -0.078924   -0.041955      -0.131287
# OutboundCalls                 -0.161659  -0.087810   -0.034233      -0.123555
# InboundCalls                  -0.140464  -0.074389   -0.029282      -0.095275
# PeakCallsInOut                -0.168677  -0.067606   -0.034766      -0.093772
# OffPeakCallsInOut             -0.251660  -0.106866   -0.050252      -0.138036
# DroppedBlockedCalls           -0.183660  -0.050291   -0.040248      -0.094934
# CallForwardingCalls           -0.009770   0.004395   -0.004594      -0.005017
# CallWaitingCalls              -0.125457  -0.028102   -0.022170      -0.058542
# MonthsInService                0.249405   0.015919    0.035929       0.079479
# UniqueSubs                     0.143693   0.038654    0.021784       0.050760
# ActiveSubs                     0.205170   0.061934    0.036648       0.110404
# ServiceArea                   -0.005390  -0.065517   -0.009567      -0.014673
# Handsets                      -0.046624  -0.060087   -0.005632      -0.052843
# HandsetModels                 -0.043022  -0.061075   -0.009927      -0.051739
# CurrentEquipmentDays           0.240021   0.066445    0.041805       0.113525
# AgeHH1                         0.235994   0.151389    0.144352       0.512042
# AgeHH2                         0.197072   0.169917    0.135171       0.593212
# ChildrenInHH                   0.090221   0.138525    0.075059       0.409205
# HandsetRefurbished            -0.025906  -0.021311   -0.006175      -0.014506
# HandsetWebCapable             -0.091020  -0.031005   -0.008492      -0.053023
# TruckOwner                     0.106947   0.125341    0.047891       0.300584
# RVOwner                        0.089889   0.085680    0.046732       0.187394
# Homeownership                  0.238266   0.167520    0.125143       0.471082
# BuysViaMailOrder               0.197686   0.153004    0.166131       0.461329
# RespondsToMailOffers           0.202787   0.153066    0.171110       0.466781
# OptOutMailings                 0.059670   0.031615    0.035213       0.062796
# NonUSTravel                    0.096570   0.043699    0.182910       0.149755
# OwnsComputer                   0.159768   0.127221    0.195885       0.322574
# HasCreditCard                  0.231350   0.127748    0.111932       0.420653
# RetentionCalls                -0.007185  -0.015418   -0.007885      -0.022422
# RetentionOffersAccepted       -0.003189  -0.007454   -0.004661      -0.013750
# NewCellphoneUser               0.003570  -0.028192    0.004007      -0.005473
# NotNewCellphoneUser            0.063926   0.008357    0.011489       0.011417
# ReferralsMadeBySubscriber     -0.007739  -0.003367    0.001576      -0.014295
# IncomeGroup                   -0.269026  -0.202348   -0.136354      -0.483221
# OwnsMotorcycle                 0.037209   0.038921    0.002471       0.066298
# AdjustmentsToCreditRating      0.037843  -0.016815    0.015252       0.000052
# HandsetPrice                  -0.108411  -0.038675   -0.013902      -0.078936
# MadeCallToRetentionTeam       -0.008632  -0.016188   -0.006703      -0.021305
# CreditRating                   1.000000   0.127929    0.092100       0.210260
# PrizmCode                      0.127929   1.000000    0.047105       0.191056
# Occupation                     0.092100   0.047105    1.000000       0.119808
# MaritalStatus                  0.210260   0.191056    0.119808       1.000000
#
# [57 rows x 57 columns]

# %%
import numpy as np
df_corr = df_encoding.corr()
df_corr['abs_Churn'] = df_corr['Churn'].apply(np.abs)
df_corr = df_corr[['Churn','abs_Churn']]
df_corr.sort_values(by='abs_Churn', ascending=False)
# Out:
#                               Churn  abs_Churn
# Churn                      1.000000   1.000000
# CurrentEquipmentDays       0.102513   0.102513
# HandsetWebCapable         -0.062409   0.062409
# MadeCallToRetentionTeam    0.060577   0.060577
# TotalRecurringCharge      -0.058945   0.058945
# RetentionCalls             0.058422   0.058422
# MonthlyMinutes            -0.050165   0.050165
# CreditRating               0.047741   0.047741
# OffPeakCallsInOut         -0.040955   0.040955
# HandsetModels             -0.040470   0.040470
# PeakCallsInOut            -0.039527   0.039527
# ReceivedCalls             -0.037097   0.037097
# CustomerCareCalls         -0.035331   0.035331
# RetentionOffersAccepted    0.034511   0.034511
# InboundCalls              -0.033855   0.033855
# Handsets                  -0.033730   0.033730
# PercChangeMinutes         -0.033194   0.033194
# UniqueSubs                 0.032839   0.032839
# OutboundCalls             -0.032489   0.032489
# HandsetRefurbished         0.030026   0.030026
# AgeHH1                    -0.028761   0.028761
# UnansweredCalls           -0.028192   0.028192
# CallWaitingCalls          -0.025509   0.025509
# ThreewayCalls             -0.023716   0.023716
# RespondsToMailOffers      -0.023082   0.023082
# BuysViaMailOrder          -0.021884   0.021884
# DirectorAssistedCalls     -0.019714   0.019714
# AgeHH2                    -0.017577   0.017577
# MonthsInService            0.017544   0.017544
# AdjustmentsToCreditRating -0.016123   0.016123
# OverageMinutes             0.015301   0.015301
# DroppedCalls              -0.015062   0.015062
# Homeownership             -0.013716   0.013716
# ActiveSubs                 0.013049   0.013049
# PercChangeRevenues         0.013015   0.013015
# IncomeGroup                0.012982   0.012982
# DroppedBlockedCalls       -0.012353   0.012353
# MonthlyRevenue            -0.012065   0.012065
# ReferralsMadeBySubscriber -0.011390   0.011390
# RoamingCalls               0.010955   0.010955
# ChildrenInHH               0.009505   0.009505
# HasCreditCard             -0.009204   0.009204
# OwnsMotorcycle             0.007700   0.007700
# NewCellphoneUser          -0.007639   0.007639
# NotNewCellphoneUser        0.006900   0.006900
# Occupation                -0.005276   0.005276
# PrizmCode                  0.005204   0.005204
# TruckOwner                -0.004873   0.004873
# MaritalStatus             -0.004567   0.004567
# BlockedCalls              -0.004474   0.004474
# RVOwner                   -0.003280   0.003280
# CallForwardingCalls       -0.003161   0.003161
# ServiceArea                0.003104   0.003104
# NonUSTravel               -0.002816   0.002816
# OwnsComputer              -0.001231   0.001231
# OptOutMailings             0.000880   0.000880
# HandsetPrice               0.000044   0.000044

# %%
from collections import namedtuple
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 고객 매달 사용 평균 통화 시간 boxplot

# %%
sns.boxplot(x=df_encoding['MonthlyMinutes'])
# Out:
# <Axes: xlabel='MonthlyMinutes'>

# %% [markdown]
# ## 고객 매달 지불하는 평균 요금 boxplot

# %%
sns.boxplot(x=df_encoding['MonthlyRevenue'])
# Out:
# <Axes: xlabel='MonthlyRevenue'>

# %% [markdown]
# ## 반복적으로 청구되는 월간 요금 boxplot

# %%
sns.boxplot(x=df_encoding['TotalRecurringCharge'])
# Out:
# <Axes: xlabel='TotalRecurringCharge'>

# %%
plt.rcParams['font.family'] = 'NanumGothic' # 폰트 지정 (나눔고딕)

# %%
plt.scatter(df_encoding['Handsets'] , y=df_encoding['HandsetModels'])
plt.xlabel('보유 핸드폰 수', fontsize=18)
plt.ylabel('사용 핸드폰 수', fontsize=18)
# Out:
# Text(0, 0.5, '사용 핸드폰 수')

# %% [markdown]
# ## 주 가구원의 연령 boxplot

# %%
sns.boxplot(data=df_encoding['AgeHH1'])
# Out:
# <Axes: ylabel='AgeHH1'>

# %% [markdown]
# ## 두 번째 가구원의 연령 boxplot

# %%
sns.boxplot(data=df_encoding['AgeHH2'].values)
# Out:
# <Axes: >

# %% [markdown]
# ## 주 가구원 연령 별 유지, 이탈 비율

# %%
plt.hist(x = [df_encoding.AgeHH1[df_encoding.Churn == 0 ], df_encoding.AgeHH1[df_encoding.Churn == 1 ]], 
            bins = 8, histtype='barstacked', label=['유지', '이탈'])
plt.legend()

# %% [markdown]
# ## 3. 데이터 전처리

# %% [markdown]
# ### 3.1 연령 구간화

# %%
'''
 구간   : [연령 최소, 20, 40, 연령 최대 + 1]
 라벨링 : ['short','middle', 'long']
'''
agehh1_bins = [df_encoding.AgeHH1.min(), 20, 40, df_encoding.AgeHH1.max() + 1]
agehh2_bins = [df_encoding.AgeHH2.min(), 20, 40, df_encoding.AgeHH2.max() + 1]
grooup_names = ['short','middle', 'long']
categorise_1  = pd.cut(df_encoding['AgeHH1'], agehh1_bins, labels=grooup_names, right=False)
categorise_2  = pd.cut(df_encoding['AgeHH2'], agehh2_bins, labels=grooup_names, right=False)

# %%
df_encoding['aggh1_panel']  = categorise_1
df_encoding['aggh2_panel']  = categorise_2

# %% [markdown]
# ## 4. 모델 학습

# %% [markdown]
# ## 5. 모델 검증 및 튜닝
