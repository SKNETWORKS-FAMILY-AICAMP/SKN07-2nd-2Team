# %% [markdown]
# # 2024.12.16.월 day36

# %% [markdown]
# ## 0. 패키지 임포트

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 데이터 불러오기

# %%
pwd
# Out:
# '/home/encore/workspace/내 코드'

# %%
# df_tt = pd.read_csv('../data/prj2_20241216/cell2cellholdout.csv')
# df_tt.isnull().sum()

# %%
import pandas as pd

df_raw = pd.read_csv('../data/prj2_20241216/cell2celltrain.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %% [markdown]
# ### 컬럼 확인
#
# CustomerID: 고객을 고유하게 식별하는 ID.
# Churn: 고객이 서비스를 해지했는지를 나타내는 컬럼. 예: 'Yes' (해지) 또는 'No' (유지).
# MonthlyRevenue: 고객이 매달 지불하는 평균 요금.
# MonthlyMinutes: 고객이 매달 사용한 평균 통화 시간(분 단위).
# TotalRecurringCharge: 반복적으로 청구되는 월간 요금.
# DirectorAssistedCalls: 상담원의 도움을 받은 통화 횟수.
# OverageMinutes: 정해진 요금제 통화 시간을 초과한 통화 시간(분 단위).
# RoamingCalls: 로밍 상태에서의 통화 횟수.
# PercChangeMinutes: 고객의 통화 시간 변동 비율.
# PercChangeRevenues: 고객의 월간 요금 변동 비율.
# DroppedCalls: 통화 중 끊긴 횟수.
# BlockedCalls: 통화 연결이 실패한 횟수.
# UnansweredCalls: 부재중 전화(응답하지 않은 통화) 횟수.
# CustomerCareCalls: 고객 센터에 걸려온 전화 횟수.
# ThreewayCalls: 삼자 통화 횟수.
# ReceivedCalls: 수신 통화 횟수.
# OutboundCalls: 발신 통화 횟수.
# InboundCalls: 수신 통화 횟수.
# PeakCallsInOut: 피크 시간대 발신 및 수신 통화 횟수.
# OffPeakCallsInOut: 비피크 시간대 발신 및 수신 통화 횟수.
# DroppedBlockedCalls: 끊긴 통화와 연결 실패 통화의 총합.
# CallForwardingCalls: 착신 전환된 통화 횟수.
# CallWaitingCalls: 통화 대기 중인 통화 횟수.
# MonthsInService: 고객이 서비스를 이용한 기간(개월 수).
# UniqueSubs: 계정에 연결된 고유 사용자 수.
# ActiveSubs: 현재 활성화된 사용자 수.
# ServiceArea: 고객이 속한 서비스 지역.
# Handsets: 고객이 보유한 휴대폰 수.
# HandsetModels: 고객이 사용하는 휴대폰 모델 수.
# CurrentEquipmentDays: 현재 휴대폰을 사용한 일수.
# AgeHH1: 주 가구원의 연령.
# AgeHH2: 두 번째 가구원의 연령.
# ChildrenInHH: 가구 내 자녀의 유무.
# HandsetRefurbished: 리퍼비시 휴대폰 사용 여부.
# HandsetWebCapable: 웹 접속 가능한 휴대폰 사용 여부.
# TruckOwner: 트럭 소유 여부.
# RVOwner: RV(레저용 차량) 소유 여부.
# Homeownership: 주택 소유 여부.
# BuysViaMailOrder: 우편 주문으로 물건을 구매한 적이 있는지 여부.
# RespondsToMailOffers: 우편으로 온 프로모션 제안에 반응했는지 여부.
# OptOutMailings: 우편물 수신 거부 여부.
# NonUSTravel: 미국 외 국가로 여행 경험 여부.
# OwnsComputer: 컴퓨터 소유 여부.
# HasCreditCard: 신용카드 소유 여부.
# RetentionCalls: 서비스 유지 관련 전화 횟수.
# RetentionOffersAccepted: 서비스 유지 제안을 수락한 횟수.
# NewCellphoneUser: 새 휴대폰 사용자 여부.
# NotNewCellphoneUser: 기존 휴대폰 사용자 여부.
# ReferralsMadeBySubscriber: 가입자가 만든 추천 수.
# IncomeGroup: 소득 수준을 나타내는 그룹 (1~n 수준).
# OwnsMotorcycle: 오토바이 소유 여부.
# AdjustmentsToCreditRating: 신용 등급 조정 횟수.
# HandsetPrice: 휴대폰 가격대.
# MadeCallToRetentionTeam: 서비스 유지 팀에 전화한 적이 있는지 여부.
# CreditRating: 고객의 신용 등급.
# PrizmCode: 고객의 라이프스타일 세그먼트를 나타내는 코드.
# Occupation: 고객의 직업.
# MaritalStatus: 고객의 혼인 상태

# %% [markdown]
# ### 결측치 확인

# %%
df_raw.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# MonthlyRevenue               156
# MonthlyMinutes               156
# TotalRecurringCharge         156
# DirectorAssistedCalls        156
# OverageMinutes               156
# RoamingCalls                 156
# PercChangeMinutes            367
# PercChangeRevenues           367
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                   24
# Handsets                       1
# ...

# %%
import missingno
missingno.matrix(df_raw)
# Out:
# <Axes: >

# %% [markdown]
# ### 데이터 값 확인

# %%
df_raw.shape
# Out:
# (51047, 58)

# %%
df_raw.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
df_raw.Churn.value_counts(normalize=True)
# Out:
# Churn
# No     0.711815
# Yes    0.288185
# Name: proportion, dtype: float64

# %%
# 결측치 있는 컬럼 수 = 14
# 각 컬럼별 결측치 비율 2% 미만
# 우선 결측치 있는 행은 모두 삭제
df_drop = df_raw.dropna()

# 고객 ID 삭제
df_drop.drop(columns='CustomerID', inplace=True)
# Out:
# /tmp/ipykernel_16098/760278249.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop.drop(columns='CustomerID', inplace=True)

# %%
df_drop.shape
# Out:
# (49752, 57)

# %% [markdown]
# ## 2. 데이터 전처리

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49752 entries, 0 to 51043
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      49752 non-null  object
#  1   MonthlyRevenue             49752 non-null  float64
#  2   MonthlyMinutes             49752 non-null  float64
#  3   TotalRecurringCharge       49752 non-null  float64
#  4   DirectorAssistedCalls      49752 non-null  float64
#  5   OverageMinutes             49752 non-null  float64
#  6   RoamingCalls               49752 non-null  float64
#  7   PercChangeMinutes          49752 non-null  float64
#  8   PercChangeRevenues         49752 non-null  float64
#  9   DroppedCalls               49752 non-null  float64
#  10  BlockedCalls               49752 non-null  float64
#  11  UnansweredCalls            49752 non-null  float64
#  12  CustomerCareCalls          49752 non-null  float64
# ...

# %% [markdown]
# ### object 컬럼 라벨링

# %%
df_drop.columns[df_drop.dtypes=='object']
# Out:
# Index(['Churn', 'ServiceArea', 'ChildrenInHH', 'HandsetRefurbished',
#        'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership',
#        'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings',
#        'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'NewCellphoneUser',
#        'NotNewCellphoneUser', 'OwnsMotorcycle', 'HandsetPrice',
#        'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
#        'MaritalStatus'],
#       dtype='object')

# %%
# # Object 컬럼 내 값 확인
# for col in df_drop.columns[df_drop.dtypes=='object']:
#     print(df_drop[col].nunique())
#     print(df_drop[col].value_counts(normalize=True))
#     print()

# %%
# df_ttt = df_drop.copy()
# df_ttt['CreditRating'] = df_ttt['CreditRating'].apply(lambda x: int(x[0]))
# df_ttt.groupby(['IncomeGroup'], as_index=False)[['MonthlyRevenue']].mean()

# %%
# 민혁

# 이상치 처리

# HandsetPrice: 휴대폰 가격대
# Unknown -> 소득수준 컬럼 IncomeGroup 로 그룹화해서 평균값 채워넣기

df_encoding = df_drop.copy()

price_data = df_encoding[df_encoding.HandsetPrice != 'Unknown']
price_data.loc[:,'HandsetPrice'] = price_data['HandsetPrice'].astype('int64')
handset_mean_price = price_data.groupby(['IncomeGroup'])[['HandsetPrice']].mean()

for i,y in handset_mean_price.iterrows():
    df_encoding.loc[(df_encoding.HandsetPrice == 'Unknown') & (df_encoding.IncomeGroup == i), 'HandsetPrice'] = round(y.values[0])

df_encoding['HandsetPrice'] = df_encoding['HandsetPrice'].astype('int64')

# %%
# 재철

# 범주형 컬럼 라벨링

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# CreditRating: 소득수준 그룹 (순서 변환)
df_encoding['IncomeGroup'] = df_encoding['IncomeGroup'].apply(lambda x: 10-x)

# CreditRating: 신용등급 (순서 변환)
credit_rating_mapping = { '1-Highest': 7, '2-High': 6, '3-Good': 5, '4-Medium': 4, '5-Low': 3, '6-VeryLow': 2, '7-Lowest': 1 }
df_encoding['CreditRating'] = df_encoding['CreditRating'].map(credit_rating_mapping)

# PrizmCode: 라이프스타일 구분 (라벨인코딩)
df_encoding['PrizmCode'] = le.fit_transform(df_encoding['PrizmCode'])  
# Occupation: 직업 (라벨인코딩)
df_encoding['Occupation'] = le.fit_transform(df_encoding['Occupation'])
# ServiceArea: 서비스 지역 (라벨인코딩)
df_encoding['ServiceArea'] = le.fit_transform(df_encoding['ServiceArea'])

# %%
# 수민

# BIT 여부 컬럼
# No/Yes = 0/1 라벨링

col_object = df_encoding.columns[df_encoding.dtypes=='object']
col_bit = [col for col in col_object if 'Yes' in list(df_encoding[col].unique())]

# MaritalStatus: 혼인 여부 (Yes/No/Unknown)
col_bit.remove('MaritalStatus')
df_encoding['MaritalStatus'] = df_encoding['MaritalStatus'].apply(lambda x: -1 if x == 'Unknown' else x)
df_encoding['MaritalStatus'] = df_encoding['MaritalStatus'].apply(lambda x: 1 if x == 'Yes' else 0)

# Homeownership: 주택 소유 여부 (Known/Unknown)
df_encoding['Homeownership'] = df_encoding['Homeownership'].apply(lambda x: 1 if x == 'Known' else 0)

# 기타 여부 컬럼들 (Yes/No)
for col in col_bit:
    df_encoding[col] = df_encoding[col].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df_encoding.to_csv('../data/prj2_20241216/df_encoding.csv', encoding='utf-8', index=False)

# %%
df_encoding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49752 entries, 0 to 51043
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      49752 non-null  int64
#  1   MonthlyRevenue             49752 non-null  float64
#  2   MonthlyMinutes             49752 non-null  float64
#  3   TotalRecurringCharge       49752 non-null  float64
#  4   DirectorAssistedCalls      49752 non-null  float64
#  5   OverageMinutes             49752 non-null  float64
#  6   RoamingCalls               49752 non-null  float64
#  7   PercChangeMinutes          49752 non-null  float64
#  8   PercChangeRevenues         49752 non-null  float64
#  9   DroppedCalls               49752 non-null  float64
#  10  BlockedCalls               49752 non-null  float64
#  11  UnansweredCalls            49752 non-null  float64
#  12  CustomerCareCalls          49752 non-null  float64
# ...

# %% [markdown]
# ### 상관관계 확인

# %%
# # 혼인여부 관련 컬럼 상관관계 확인
# df_corr = df_encoding[['Churn', 'MaritalStatus','AgeHH1','AgeHH2','ChildrenInHH']].corr()

# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.figure(figsize=(5,5))
# sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_corr = df_encoding.corr()
plt.figure(figsize=(20,20))
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
df_corr = df_encoding.corr()
df_corr['abs_Churn'] = df_corr['Churn'].apply(np.abs)
df_corr = df_corr[['Churn','abs_Churn']]
df_corr.sort_values(by='abs_Churn', ascending=False)
# Out:
#                               Churn  abs_Churn
# Churn                      1.000000   1.000000
# CurrentEquipmentDays       0.102513   0.102513
# HandsetWebCapable         -0.062409   0.062409
# MadeCallToRetentionTeam    0.060577   0.060577
# TotalRecurringCharge      -0.058945   0.058945
# RetentionCalls             0.058422   0.058422
# MonthlyMinutes            -0.050165   0.050165
# CreditRating               0.047741   0.047741
# OffPeakCallsInOut         -0.040955   0.040955
# HandsetModels             -0.040470   0.040470
# PeakCallsInOut            -0.039527   0.039527
# ReceivedCalls             -0.037097   0.037097
# CustomerCareCalls         -0.035331   0.035331
# RetentionOffersAccepted    0.034511   0.034511
# InboundCalls              -0.033855   0.033855
# Handsets                  -0.033730   0.033730
# PercChangeMinutes         -0.033194   0.033194
# UniqueSubs                 0.032839   0.032839
# OutboundCalls             -0.032489   0.032489
# ...

# %% [markdown]
# ## 3. EDA

# %% [markdown]
# ### 고객 매달 사용 평균 통화 시간 boxplot

# %%
sns.boxplot(x=df_encoding['MonthlyMinutes'])
# Out:
# <Axes: xlabel='MonthlyMinutes'>

# %% [markdown]
# ### 고객 매달 지불하는 평균 요금 boxplot

# %%
sns.boxplot(x=df_encoding['MonthlyRevenue'])
# Out:
# <Axes: xlabel='MonthlyRevenue'>

# %% [markdown]
# ### 반복적으로 청구되는 월간 요금 boxplot

# %%
sns.boxplot(x=df_encoding['TotalRecurringCharge'])
# Out:
# <Axes: xlabel='TotalRecurringCharge'>

# %%
plt.rcParams['font.family'] = 'NanumGothic' # 폰트 지정 (나눔고딕)
plt.scatter(df_encoding['Handsets'] , y=df_encoding['HandsetModels'])
plt.xlabel('보유 핸드폰 수', fontsize=18)
plt.ylabel('사용 핸드폰 수', fontsize=18)
# Out:
# Text(0, 0.5, '사용 핸드폰 수')

# %% [markdown]
# ### 주 가구원의 연령 boxplot

# %%
sns.boxplot(data=df_encoding['AgeHH1'])
# Out:
# <Axes: ylabel='AgeHH1'>

# %% [markdown]
# ### 두 번째 가구원의 연령 boxplot

# %%
sns.boxplot(data=df_encoding['AgeHH2'].values)
# Out:
# <Axes: >

# %% [markdown]
# ### 주 가구원 연령 별 유지, 이탈 비율

# %%
plt.hist(x = [df_encoding.AgeHH1[df_encoding.Churn == 0 ], df_encoding.AgeHH1[df_encoding.Churn == 1 ]], 
            bins = 8, histtype='barstacked', label=['유지', '이탈'])
plt.legend()

# %% [markdown]
# ## 4. 모델 학습

# %% [markdown]
# ### 데이터셋 분리 (8:2)

# %%
# df_encoding

# %%
import pandas as pd
df_encoding = pd.read_csv('../data/prj2_20241216/df_encoding.csv', encoding='utf-8')

# %%
from sklearn.model_selection import train_test_split

df_X = df_encoding.copy()
df_y =  df_X['Churn']
del df_X['Churn']

# train/valid = 8:2
X_train, X_val, y_train, y_val = train_test_split(df_X, df_y, test_size = 0.2, random_state=42)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# print(X_test.shape, y_test.shape)
# Out:
# (39801, 56) (39801,)
# (9951, 56) (9951,)

# %% [markdown]
# ### 모델 검증 결과 함수화

# %%
# 분류 모델 혼합행렬 결과 print 함수
def matrix_print(model_nm, model, y_preds, y_val):
    from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
    print('-'*50)
    print(f'[{model_nm}]', '\n')
    
    print('  Accuracy: ', round(accuracy_score(y_preds, y_val), 3))
    print('  Recall: ', round(recall_score(y_preds, y_val), 3))
    print('  Precision: ', round(precision_score(y_preds, y_val), 3))
    print('  F1 Score: ', round(f1_score(y_preds, y_val), 3))
    print('  AUC Score: ', round(roc_auc_score(y_val, y_preds), 3))
    
    print(f'\nConfusion Matrix: \n{confusion_matrix(y_val, y_preds)}\n')

# %% [markdown]
# ### ROC 곡선 함수

# %%
# ROC-Curve 데이터프레임 생성
def make_roc_curve(list_results, model_nm, y_preds_proba, y_val):
    from sklearn.metrics import roc_curve, roc_auc_score
    fpr, tpr, _ = roc_curve(y_val, y_preds_proba)
    auc = roc_auc_score(y_val, y_preds_proba)
    list_result = [model_nm, fpr, tpr, auc]
    list_results.append(list_result)
    # result_table = result_table.append({'classifiers':model_nm, 'fpr':fpr, 'tpr':tpr, 'auc':auc}, ignore_index=True)
    return list_results

# ROC-Curve 시각화
def show_roc_curve(list_results):
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    result_table = pd.DataFrame(list_results, columns=['classifiers', 'fpr', 'tpr', 'auc'])
    result_table = result_table.set_index('classifiers')
    fig = plt.figure(figsize=(8,6))
    for i in result_table.index:
        plt.plot(result_table.loc[i]['fpr'],
                 result_table.loc[i]['tpr'],
                 label='{}, AUC={:.3f}'.format(i, result_table.loc[i]['auc']))
        
    plt.plot([0,1], [0,1], color='orange', linestyle='--')
    plt.xticks(np.arange(0.0, 1.1, step=0.1))
    plt.xlabel("Flase Positive Rate", fontsize=15)
    plt.yticks(np.arange(0.0, 1.1, step=0.1))
    plt.ylabel("True Positive Rate", fontsize=15)
    plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
    plt.legend(prop={'size':13}, loc='lower right')
    plt.show()

# %% [markdown]
# ### ML 모델 학습 함수

# %%
def ml_model_train(X_train, y_train, X_val, y_val):

    # ROC-Curve
    list_results = list()

    # 로지스틱 회귀
    from sklearn.linear_model import LogisticRegression
    model_lr = LogisticRegression(max_iter=1000, random_state=42)
    model_lr.fit(X_train, y_train)
    y_preds_lr = model_lr.predict(X_val)
    y_predict_proba_lr = model_lr.predict_proba(X_val)[:,1]
    matrix_print('LogisticRegression', model_lr, y_preds_lr, y_val)
    list_results = make_roc_curve(list_results, 'LogisticRegression', y_predict_proba_lr, y_val)

    # Decision Tree
    from sklearn.tree import DecisionTreeClassifier
    model_dt = DecisionTreeClassifier(max_depth=3, random_state=42)
    model_dt.fit(X_train, y_train)
    y_preds_dt = model_dt.predict(X_val)
    y_predict_proba_dt = model_dt.predict_proba(X_val)[:,1]
    matrix_print('DecisionTree', model_dt, y_preds_dt, y_val)
    list_results = make_roc_curve(list_results, 'DecisionTree', y_predict_proba_dt, y_val)

    # RandomForest
    from sklearn.ensemble import RandomForestClassifier
    model_rf = RandomForestClassifier(n_jobs=5, random_state=42, max_depth=20)
    model_rf.fit(X_train, y_train)
    y_preds_rf = model_rf.predict(X_val)
    y_predict_proba_rf = model_rf.predict_proba(X_val)[:,1]
    matrix_print('RandomForest', model_rf, y_preds_rf, y_val)
    list_results = make_roc_curve(list_results, 'RandomForest', y_predict_proba_rf, y_val)

    # LightGBM
    from lightgbm import LGBMClassifier
    model_lgb = LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
    model_lgb.fit(X_train, y_train)
    y_preds_lgb = model_lgb.predict(X_val)
    y_predict_proba_lgb = model_lgb.predict_proba(X_val)[:,1]
    matrix_print('LightGBM', model_lgb, y_preds_lgb, y_val)
    list_results = make_roc_curve(list_results, 'LightGBM', y_predict_proba_lgb, y_val)

    # XGBoost
    from xgboost import XGBClassifier
    model_xgb = XGBClassifier(n_estimators=100, learning_rate=0.1, use_label_encoder=False, eval_metric='logloss', random_state=42)
    model_xgb.fit(X_train, y_train)
    y_preds_xgb = model_xgb.predict(X_val)
    y_predict_proba_xgb = model_xgb.predict_proba(X_val)[:,1]
    matrix_print('XGBoost', model_xgb, y_preds_xgb, y_val)
    list_results = make_roc_curve(list_results, 'XGBoost', y_predict_proba_xgb, y_val)

    # KNN
    from sklearn.neighbors import KNeighborsClassifier
    model_kn = KNeighborsClassifier()
    model_kn.fit(X_train, y_train)
    # model_kn.score(X_val_corr_ss, y_val)
    y_preds_kn = model_kn.predict(X_val)
    y_predict_proba_kn = model_kn.predict_proba(X_val)[:,1]
    matrix_print('KNN', model_kn, y_preds_kn, y_val)
    list_results = make_roc_curve(list_results, 'KNN', y_predict_proba_kn, y_val)

    # # SVM
    # from sklearn.svm import SVC
    # model_svm = SVC(C=0.1, gamma=10, kernel='rbf')
    # model_svm.fit(X_train, y_train)
    # y_preds_svc = model_svm.predict(X_val)
    # y_predict_proba_svm = model_svm.predict_proba(X_val)[:,1]
    # matrix_print('SVM', model_svm, y_preds_svc, y_val)
    # list_results = make_roc_curve(list_results, 'SVM', y_predict_proba_svm, y_val)

    # ROC-Curve 시각화
    show_roc_curve(list_results)

    # 학습한 모델 객체 반환
    model_result = dict()
    model_result['model_lr'] = model_lr
    model_result['model_dt'] = model_dt
    model_result['model_rf'] = model_rf
    model_result['model_lgb'] = model_lgb
    model_result['model_xgb'] = model_xgb
    model_result['model_kn'] = model_kn
    # model_result['model_svm'] = model_svm

    return model_result

# %%
model_result_raw = ml_model_train(X_train, y_train, X_val, y_val)
# Out:
# /home/encore/workspace/pytorch/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.704
#   Recall:  0.429
#   Precision:  0.025
#   F1 Score:  0.047
#   AUC Score:  0.506
#
# Confusion Matrix:
# [[6938   96]
#  [2845   72]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.709
#   Recall:  0.606
#   Precision:  0.02
#   F1 Score:  0.038
#   AUC Score:  0.507
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### DL - DNN

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.utils.data import DataLoader, TensorDataset

# 데이터 정규화 (특징들을 스케일링)
ss = StandardScaler()   # 데이터 정규화를 위한 StandardScaler 사용
ss.fit(X_train)
X_train_ss = ss.transform(X_train) # 데이터를 평균 0, 표준편차 1로 변환
X_val_ss = ss.transform(X_val) # 데이터를 평균 0, 표준편차 1로 변환

# 데이터를 PyTorch 텐서 형식으로 변환
X_train_tensor = torch.tensor(X_train_ss, dtype=torch.float32) # 훈련 데이터
y_train_tensor = torch.tensor(np.array(y_train), dtype=torch.float32).view(-1, 1) # 타겟 데이터 (이진 분류이므로 2D 텐서로 변환)
X_val_tensor = torch.tensor(X_val_ss, dtype=torch.float32) # 검증 데이터
y_val_tensor = torch.tensor(np.array(y_val), dtype=torch.float32).view(-1, 1)   # 타겟 데이터(이진 분류이므로 2D 텐서로 변환)

# DataLoader로 배치 처리 (훈련 데이터, 테스트 데이터)
train_data = TensorDataset(X_train_tensor, y_train_tensor)  # 훈련 데이터셋 생성
val_data = TensorDataset(X_val_tensor, y_val_tensor) # 테스트 데이터셋 생성
train_dl = DataLoader(train_data, batch_size=64, shuffle=True)  # 훈련 데이터셋에 배치 크기 설정, 데이터를 섞음
val_dl = DataLoader(val_data, batch_size=64, shuffle=False)   # 테스트 데이터셋에 배치 크기 설정

# %%
# 신경망 모델 정의
class tele_churn_predict(nn.Module):
    def __init__(self):
        super(tele_churn_predict, self).__init__()
        # 개의 입력 특징을 받아들이는 첫 번째 Fully Connected Layer
        self.fc1 = nn.Linear(56, 32)  # 개의 입력 특징
        self.fc2 = nn.Linear(32, 16)  # 32개의 출력에서 16개로 변환
        self.fc3 = nn.Linear(16, 1)  # 16개의 출력에서 1개의 생존 확률 값으로 변환
        self.sigmoid = nn.Sigmoid()  # 생존 확률을 0과 1 사이로 변환하기 위한 Sigmoid 함수

    def forward(self, x):
        x = nn.ReLU()(self.fc1(x))  # 첫 번째 레이어 후 ReLU 활성화 함수
        x = nn.ReLU()(self.fc2(x))  # 두 번째 레이어 후 ReLU 활성화 함수
        x = self.fc3(x)  # 세 번째 레이어
        x = self.sigmoid(x)  # 출력값을 확률로 변환
        return x

# 모델 인스턴스화
model = tele_churn_predict()
# 손실 함수와 옵티마이저 설정
loss_fn = nn.BCELoss()  # 이진 분류 문제이므로 Binary Cross Entropy 손실 함수 사용
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  # Adam 옵티마이저 사용

# 훈련 루프
num_epochs = 20  # 훈련할 에포크 수 설정
for epoch in range(num_epochs):
    model.train()  # 모델을 훈련 모드로 설정
    total_loss = 0  # 손실을 누적할 변수
    correct = 0  # 정확도를 계산할 변수
    for X_batch, y_batch in train_dl:
        optimizer.zero_grad()  # 기울기 초기화
        output = model(X_batch)  # 순전파: 배치 데이터를 모델에 통과시켜 예측값 생성
        loss = loss_fn(output, y_batch)  # 손실 계산
        loss.backward()  # 역전파
        optimizer.step()  # 옵티마이저로 파라미터 업데이트
        total_loss += loss.item()  # 손실값 누적
        predicted = (output > 0.5).float()  # 예측값이 0.5보다 크면 생존, 작으면 사망
        correct += (predicted == y_batch).sum().item()  # 정확도 계산

    # 에포크마다 손실과 정확도 출력
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(train_dl):.4f}, Accuracy: {correct/len(train_dl.dataset):.4f}")
# Out:
# Epoch 1/20, Loss: 0.5950, Accuracy: 0.7089
# Epoch 2/20, Loss: 0.5803, Accuracy: 0.7146
# Epoch 3/20, Loss: 0.5763, Accuracy: 0.7145
# Epoch 4/20, Loss: 0.5735, Accuracy: 0.7153
# Epoch 5/20, Loss: 0.5713, Accuracy: 0.7164
# Epoch 6/20, Loss: 0.5689, Accuracy: 0.7169
# Epoch 7/20, Loss: 0.5672, Accuracy: 0.7182
# Epoch 8/20, Loss: 0.5651, Accuracy: 0.7198
# Epoch 9/20, Loss: 0.5636, Accuracy: 0.7205
# Epoch 10/20, Loss: 0.5617, Accuracy: 0.7202
# Epoch 11/20, Loss: 0.5597, Accuracy: 0.7224
# Epoch 12/20, Loss: 0.5586, Accuracy: 0.7223
# Epoch 13/20, Loss: 0.5558, Accuracy: 0.7234
# Epoch 14/20, Loss: 0.5552, Accuracy: 0.7241
# Epoch 15/20, Loss: 0.5527, Accuracy: 0.7262
# Epoch 16/20, Loss: 0.5522, Accuracy: 0.7251
# Epoch 17/20, Loss: 0.5500, Accuracy: 0.7270
# Epoch 18/20, Loss: 0.5482, Accuracy: 0.7268
# Epoch 19/20, Loss: 0.5472, Accuracy: 0.7266
# Epoch 20/20, Loss: 0.5465, Accuracy: 0.7290

# %% [markdown]
# ## 5. 모델 검증 및 튜닝

# %% [markdown]
# ### 표준화

# %%
# 표준화
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_scaler = sc.transform(X_train)
X_val_scaler = sc.transform(X_val)

model_result_scaler = ml_model_train(X_train_scaler, y_train, X_val_scaler, y_val)
# Out:
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.704
#   Recall:  0.437
#   Precision:  0.03
#   F1 Score:  0.056
#   AUC Score:  0.507
#
# Confusion Matrix:
# [[6922  112]
#  [2830   87]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.709
#   Recall:  0.606
#   Precision:  0.02
#   F1 Score:  0.038
#   AUC Score:  0.507
#
# Confusion Matrix:
# [[6997   37]
#  [2860   57]]
#
# --------------------------------------------------
# [RandomForest]
#
#   Accuracy:  0.716
#   Recall:  0.669
#   Precision:  0.064
#   F1 Score:  0.118
#   AUC Score:  0.526
#
# Confusion Matrix:
# [[6941   93]
#  [2729  188]]
#
# [LightGBM] [Info] Number of positive: 11328, number of negative: 28473
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %% [markdown]
# ### 정규화

# %%
# 정규화
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
mm.fit(X_train)
X_train_minmax = mm.transform(X_train)
X_val_minmax = mm.transform(X_val)

model_result_minmax = ml_model_train(X_train_minmax, y_train, X_val_minmax, y_val)
# Out:
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.704
#   Recall:  0.412
#   Precision:  0.019
#   F1 Score:  0.037
#   AUC Score:  0.504
#
# Confusion Matrix:
# [[6954   80]
#  [2861   56]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.709
#   Recall:  0.606
#   Precision:  0.02
#   F1 Score:  0.038
#   AUC Score:  0.507
#
# Confusion Matrix:
# [[6997   37]
#  [2860   57]]
#
# --------------------------------------------------
# [RandomForest]
#
#   Accuracy:  0.717
#   Recall:  0.674
#   Precision:  0.065
#   F1 Score:  0.119
#   AUC Score:  0.526
#
# Confusion Matrix:
# [[6942   92]
#  [2727  190]]
#
# [LightGBM] [Info] Number of positive: 11328, number of negative: 28473
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %% [markdown]
# ### 변수 선택 - 상관계수 기준

# %%
# target(Price)와 가장 correlated 된 features 를 k개 고르기.
## f_regresison, SelectKBest 불러오기.
from sklearn.feature_selection import f_regression, SelectKBest
## selctor 정의하기.
selector = SelectKBest(score_func=f_regression, k=20)
## 학습데이터에 fit_transform 
X_train_selected = selector.fit_transform(X_train, y_train)
# X_train_selected.shape

# ## 테스트 데이터는 transform
# X_val_selected = selector.transform(X_val)

selected_mask = selector.get_support()
feature_20 = X_train.columns[selected_mask]
feature_20
# Out:
# Index(['MonthlyMinutes', 'TotalRecurringCharge', 'PercChangeMinutes',
#        'CustomerCareCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls',
#        'PeakCallsInOut', 'OffPeakCallsInOut', 'UniqueSubs', 'Handsets',
#        'HandsetModels', 'CurrentEquipmentDays', 'AgeHH1', 'HandsetRefurbished',
#        'HandsetWebCapable', 'RetentionCalls', 'RetentionOffersAccepted',
#        'MadeCallToRetentionTeam', 'CreditRating'],
#       dtype='object')

# %%
# 상관계수 기준 top20
X_train_corr = X_train[feature_20]
X_val_corr = X_val[feature_20]

model_result_corr = ml_model_train(X_train_corr, y_train, X_val_corr, y_val)
# Out:
# /home/encore/workspace/pytorch/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.705
#   Recall:  0.41
#   Precision:  0.016
#   F1 Score:  0.032
#   AUC Score:  0.503
#
# Confusion Matrix:
# [[6965   69]
#  [2869   48]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.71
#   Recall:  0.631
#   Precision:  0.022
#   F1 Score:  0.043
#   AUC Score:  0.508
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### 상관계수 top20 & 표준화

# %%
sc_corr = StandardScaler()
sc_corr.fit(X_train_corr)
X_train_corr_ss = sc_corr.transform(X_train_corr)
X_val_corr_ss = sc_corr.transform(X_val_corr)

model_result_corr_ss = ml_model_train(X_train_corr_ss, y_train, X_val_corr_ss, y_val)
# Out:
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.705
#   Recall:  0.432
#   Precision:  0.02
#   F1 Score:  0.037
#   AUC Score:  0.504
#
# Confusion Matrix:
# [[6959   75]
#  [2860   57]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.71
#   Recall:  0.631
#   Precision:  0.022
#   F1 Score:  0.043
#   AUC Score:  0.508
#
# Confusion Matrix:
# [[6996   38]
#  [2852   65]]
#
# --------------------------------------------------
# [RandomForest]
#
#   Accuracy:  0.711
#   Recall:  0.551
#   Precision:  0.08
#   F1 Score:  0.139
#   AUC Score:  0.526
#
# Confusion Matrix:
# [[6845  189]
#  [2685  232]]
#
# [LightGBM] [Info] Number of positive: 11328, number of negative: 28473
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %% [markdown]
# ### 변수 선택 - Feature Importance

# %%
# 시각화
importance = pd.DataFrame(model_result_raw['model_rf'].feature_importances_, index=X_train.columns, columns=["importance"]).sort_values(by="importance",ascending =True)

import matplotlib.pyplot as plt

importance.plot.barh(figsize=(15,10))

plt.xlabel('Importance', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %%
importance.reset_index().loc[:19]
# Out:
#                         index  importance
# 0         CallForwardingCalls    0.000478
# 1     RetentionOffersAccepted    0.001186
# 2              OwnsMotorcycle    0.001253
# 3              OptOutMailings    0.001283
# 4   AdjustmentsToCreditRating    0.002257
# 5                 NonUSTravel    0.002652
# 6   ReferralsMadeBySubscriber    0.002846
# 7     MadeCallToRetentionTeam    0.002895
# 8                     RVOwner    0.002911
# 9               HasCreditCard    0.003982
# 10             RetentionCalls    0.004029
# 11              Homeownership    0.004039
# 12               OwnsComputer    0.004077
# 13                 TruckOwner    0.004233
# 14           BuysViaMailOrder    0.004241
# 15       RespondsToMailOffers    0.004269
# 16        NotNewCellphoneUser    0.004657
# 17              MaritalStatus    0.004773
# 18               ChildrenInHH    0.004807
# 19          HandsetWebCapable    0.004919

# %%
importance = pd.DataFrame(model_result_raw['model_rf'].feature_importances_, index=X_train.columns, columns=["importance"])
importance = importance.sort_values(by="importance",ascending =False).reset_index()
importance_20 = importance.loc[:19]['index']

# Feature Importance 기준 top20
X_train_fi = X_train[importance_20]
X_val_fi = X_val[importance_20]

model_result_fi = ml_model_train(X_train_fi, y_train, X_val_fi, y_val)
# Out:
# /home/encore/workspace/pytorch/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.706
#   Recall:  0.324
#   Precision:  0.004
#   F1 Score:  0.007
#   AUC Score:  0.5
#
# Confusion Matrix:
# [[7011   23]
#  [2906   11]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.711
#   Recall:  0.633
#   Precision:  0.033
#   F1 Score:  0.062
#   AUC Score:  0.512
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### 타겟 오버샘플링

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=0)

X_train_over, y_train_over =  smote.fit_resample(X_train, y_train)

print("SMOTE 적용 전 학습용 피처/레이블 데이터 세트", X_train.shape, y_train.shape)
print("SMOTE 적용 후 학습용 피처/레이블 데이터 세트", X_train_over.shape, y_train_over.shape)
print("SMOTE 적용 전 레이블 값 분포 \n",y_train.value_counts(normalize=True))
print("SMOTE 적용 후 레이블 값 분포 \n",y_train_over.value_counts(normalize=True))
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 (39801, 56) (39801,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트 (56946, 56) (56946,)
# SMOTE 적용 전 레이블 값 분포
#  Churn
# 0    0.715384
# 1    0.284616
# Name: proportion, dtype: float64
# SMOTE 적용 후 레이블 값 분포
#  Churn
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
model_result_over = ml_model_train(X_train_over, y_train_over, X_val, y_val)
# Out:
# /home/encore/workspace/pytorch/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --------------------------------------------------
# [LogisticRegression]
#
#   Accuracy:  0.587
#   Recall:  0.342
#   Precision:  0.443
#   F1 Score:  0.386
#   AUC Score:  0.545
#
# Confusion Matrix:
# [[4549 2485]
#  [1626 1291]]
#
# --------------------------------------------------
# [DecisionTree]
#
#   Accuracy:  0.604
#   Recall:  0.364
#   Precision:  0.467
#   F1 Score:  0.409
#   AUC Score:  0.564
#
# Confusion Matrix:
# ...

# %% [markdown]
# ### 하이퍼파라미터 튜닝 - 그리드서치

# %%
# 민혁님

# %% [markdown]
# ### 파생변수 생성

# %%
# 연령 구간화
'''
 구간   : [연령 최소, 20, 40, 연령 최대 + 1]
 라벨링 : ['short','middle', 'long']
'''
agehh1_bins = [df_encoding.AgeHH1.min(), 20, 40, df_encoding.AgeHH1.max() + 1]
agehh2_bins = [df_encoding.AgeHH2.min(), 20, 40, df_encoding.AgeHH2.max() + 1]
grooup_names = ['short','middle', 'long']
categorise_1  = pd.cut(df_encoding['AgeHH1'], agehh1_bins, labels=grooup_names, right=False)
categorise_2  = pd.cut(df_encoding['AgeHH2'], agehh2_bins, labels=grooup_names, right=False)
df_encoding['aggh1_panel']  = categorise_1
df_encoding['aggh2_panel']  = categorise_2

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %% [markdown]
# ### 이상치 처리

# %%
# 연령 값이 0인 경우 결측치 이므로 처리해주면 좋음
# AgeHH1: 주 가구원의 연령.
# AgeHH2: 두 번째 가구원의 연령.
